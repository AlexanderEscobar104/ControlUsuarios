-- %% [markdown]
-- # [DatosPersonales]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DatosPersonales]    Script Date: 12/04/2023 1:14:48 ******/
CREATE DATABASE [DatosPersonales]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DatosPersonales', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\DatosPersonales.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DatosPersonales_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\DatosPersonales_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DatosPersonales] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DatosPersonales].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DatosPersonales] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DatosPersonales] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DatosPersonales] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DatosPersonales] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DatosPersonales] SET ARITHABORT OFF 
GO
ALTER DATABASE [DatosPersonales] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DatosPersonales] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DatosPersonales] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DatosPersonales] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DatosPersonales] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DatosPersonales] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DatosPersonales] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DatosPersonales] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DatosPersonales] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DatosPersonales] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DatosPersonales] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DatosPersonales] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DatosPersonales] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DatosPersonales] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DatosPersonales] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DatosPersonales] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DatosPersonales] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DatosPersonales] SET RECOVERY FULL 
GO
ALTER DATABASE [DatosPersonales] SET  MULTI_USER 
GO
ALTER DATABASE [DatosPersonales] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DatosPersonales] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DatosPersonales] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DatosPersonales] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DatosPersonales] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DatosPersonales] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'DatosPersonales', N'ON'
GO
ALTER DATABASE [DatosPersonales] SET QUERY_STORE = ON
GO
ALTER DATABASE [DatosPersonales] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
USE [DatosPersonales]
GO

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 12/04/2023 1:14:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[Id_Usuario] [bigint] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](120) NOT NULL,
	[Apellido] [varchar](120) NOT NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[Id_Usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DatosPersonales]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DatosPersonales] SET  READ_WRITE 
GO
